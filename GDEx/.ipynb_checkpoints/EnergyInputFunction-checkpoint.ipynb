# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.graphics as smgraphics
import altair as alt

# %% [markdown]
# # Data from workpackage D3.2 loaded into Dataframe
# The data that we load are from the lab-made samples, i.e. we exclude for now the real brine samples from Romania. We will us those sample later on for comparison.

# %%
df=pd.read_pickle('Data\dfLab.pickle')
#df=pd.read_csv('dfAll.csv',index_col=0)

#make columnnames less human friendly and more computer friendly
df.columns = df.columns.str.strip()\
                           .str.lower()\
                           .str.replace('+','')\
                           .str.replace('^','')\
                           .str.replace(' ', '_')\
                           .str.replace('[', '')\
                           .str.replace(']', '')\
                           .str.replace('/', '')\
                           .str.replace('_mgl','')

df.columns = df.columns.str.replace('salinity_gl','s')\
                         .str.replace('temperature','t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     146                             compression=inferred_compression,
# --> 147                             is_text=False)
#     148         try:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     405             # Python 3 and binary mode
# --> 406             f = open(path_or_buf, mode)
#     407         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data\\dfLab.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     170                 return read_wrapper(
# --> 171                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     172             # compat pickle
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     146                             compression=inferred_compression,
# --> 147                             is_text=False)
#     148         try:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     405             # Python 3 and binary mode
# --> 406             f = open(path_or_buf, mode)
#     407         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data\\dfLab.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     176     try:
# --> 177         return try_read(path)
#     178     except:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     174                 return read_wrapper(
# --> 175                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     176     try:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     146                             compression=inferred_compression,
# --> 147                             is_text=False)
#     148         try:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     405             # Python 3 and binary mode
# --> 406             f = open(path_or_buf, mode)
#     407         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data\\dfLab.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     146                             compression=inferred_compression,
# --> 147                             is_text=False)
#     148         try:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     405             # Python 3 and binary mode
# --> 406             f = open(path_or_buf, mode)
#     407         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data\\dfLab.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     170                 return read_wrapper(
# --> 171                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     172             # compat pickle
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     146                             compression=inferred_compression,
# --> 147                             is_text=False)
#     148         try:
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     405             # Python 3 and binary mode
# --> 406             f = open(path_or_buf, mode)
#     407         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data\\dfLab.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-3e32d01819a3> in <module>
# ----> 1 df=pd.read_pickle('Data\dfLab.pickle')
#       2 #df=pd.read_csv('dfAll.csv',index_col=0)
#       3
#       4 #make columnnames less human friendly and more computer friendly
#       5 df.columns = df.columns.str.strip().str.lower().str.replace('+','').str.replace('^','').str.replace(' ', '_').str.replace('[', '').str.replace(']', '').str.replace('/', '')
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     178     except:
#     179         if PY3:
# --> 180             return try_read(path, encoding='latin1')
#     181         raise
#     182
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     173             except:
#     174                 return read_wrapper(
# --> 175                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     176     try:
#     177         return try_read(path)
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     145         f, fh = _get_handle(path, 'rb',
#     146                             compression=inferred_compression,
# --> 147                             is_text=False)
#     148         try:
#     149             return func(f)
#
# ~\AnacondaProjects\CHPM2030\venv\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     404         else:
#     405             # Python 3 and binary mode
# --> 406             f = open(path_or_buf, mode)
#     407         handles.append(f)
#     408
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data\\dfLab.pickle'

# %% [markdown]
# # Correlation matrix for selected set of variables
# Below we see the correlation matrix between diffrent parameters. If we focus on the energy input per kg of metal removed we see that it correlates poorly with most parameters except the magnesium content.

# %%
smalldf=df[['energy_input_kwhkg_metal_rem.','mg','ca','li','al','t','s','ewe']].copy()
smalldf.corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col0 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col1 {
#             background-color:  #045a8d;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col2 {
#             background-color:  #d5d5e8;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col3 {
#             background-color:  #d3d4e7;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col4 {
#             background-color:  #ced0e6;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col5 {
#             background-color:  #e1dfed;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col7 {
#             background-color:  #d7d6e9;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col0 {
#             background-color:  #045b8f;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col1 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col2 {
#             background-color:  #b3c3de;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col3 {
#             background-color:  #dfddec;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col4 {
#             background-color:  #f1ebf4;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col5 {
#             background-color:  #d1d2e6;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col6 {
#             background-color:  #f7f0f7;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row1_col7 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col0 {
#             background-color:  #ede7f2;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col1 {
#             background-color:  #c6cce3;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col2 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col3 {
#             background-color:  #f0eaf4;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col4 {
#             background-color:  #fdf5fa;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col5 {
#             background-color:  #bcc7e1;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col6 {
#             background-color:  #f6eff7;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row2_col7 {
#             background-color:  #fef6fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col0 {
#             background-color:  #e4e1ef;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col1 {
#             background-color:  #e7e3f0;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col2 {
#             background-color:  #eae6f1;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col3 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col4 {
#             background-color:  #73a9cf;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col5 {
#             background-color:  #f7f0f7;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col6 {
#             background-color:  #dddbec;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row3_col7 {
#             background-color:  #dfddec;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col0 {
#             background-color:  #e9e5f1;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col3 {
#             background-color:  #7eadd1;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col4 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col5 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col6 {
#             background-color:  #e7e3f0;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row4_col7 {
#             background-color:  #ece7f2;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col0 {
#             background-color:  #f9f2f8;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col1 {
#             background-color:  #e2dfee;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col2 {
#             background-color:  #c0c9e2;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col3 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col4 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col5 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col6 {
#             background-color:  #f4eef6;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row5_col7 {
#             background-color:  #fcf4fa;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col0 {
#             background-color:  #fff7fb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col1 {
#             background-color:  #f0eaf4;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col2 {
#             background-color:  #e1dfed;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col3 {
#             background-color:  #cccfe5;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col4 {
#             background-color:  #cccfe5;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col5 {
#             background-color:  #dcdaeb;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col6 {
#             background-color:  #023858;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row6_col7 {
#             background-color:  #f9f2f8;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col0 {
#             background-color:  #d2d2e7;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col1 {
#             background-color:  #f4edf6;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col2 {
#             background-color:  #e6e2ef;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col3 {
#             background-color:  #c5cce3;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col4 {
#             background-color:  #c9cee4;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col5 {
#             background-color:  #e0dded;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col6 {
#             background-color:  #f4eef6;
#         }    #T_71ffee70_15b5_11e9_9de7_d4258bcadf72row7_col7 {
#             background-color:  #023858;
#         }</style>
# <table id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >energy_input_kwhkg_metal_rem.</th>
#         <th class="col_heading level0 col1" >mg</th>
#         <th class="col_heading level0 col2" >ca</th>
#         <th class="col_heading level0 col3" >li</th>
#         <th class="col_heading level0 col4" >al</th>
#         <th class="col_heading level0 col5" >t</th>
#         <th class="col_heading level0 col6" >s</th>
#         <th class="col_heading level0 col7" >ewe</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72level0_row0" class="row_heading level0 row0" >energy_input_kwhkg_metal_rem.</th>
#         <td id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col0" class="data row0 col0" >1</td>
#         <td id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col1" class="data row0 col1" >0.85</td>
#         <td id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col2" class="data row0 col2" >-0.0056</td>
#         <td id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col3" class="data row0 col3" >0.04</td>
#         <td id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col4" class="data row0 col4" >0.012</td>
#         <td id="T_71ffee70_15b5_11e9_9de7_d4258bcadf72row0_col5"

# %% [markdown]
# # Linear regression model for predicting the energy input
# Here we use the data from the lab samples to make a linear regression model for the energy input as a function of Mg,Ca,Salinity, Ewe and temperture. We want the output data to be restricted to the interval $]0, \infty]$, so we fit the data in log-space.

# %%
#Features selected for the regression model
X=df[['mg','ca','s','ph','t','ewe']]
X=X.fillna(0)
X=sm.add_constant(X)

#Labels selected for the regression model
Y=np.log(df['energy_input_kwhkg_metal_rem.'])

#The model fitted
est=sm.OLS(Y,X)
est=est.fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     energy_input_kwhkg_metal_rem.   R-squared:                       0.621
# Model:                                       OLS   Adj. R-squared:                  0.587
# Method:                            Least Squares   F-statistic:                     18.53
# Date:                           Fri, 11 Jan 2019   Prob (F-statistic):           1.23e-12
# Time:                                   15:27:49   Log-Likelihood:                -40.251
# No. Observations:                             75   AIC:                             94.50
# Df Residuals:                                 68   BIC:                             110.7
# Df Model:                                      6
# Covariance Type:                       nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3529      0.354      3.820      0.000       0.646       2.060
# mg             0.0016      0.000      9.010      0.000       0.001       0.002
# ca         -8.196e-06   1.57e-05     -0.521      0.604   -3.96e-05    2.32e-05
# s             -0.0050      0.002     -2.246      0.028      -0.009      -0.001
# ewe            1.7076      0.407      4.194      0.000       0.895       2.520
# t             -0.0001      0.007     -0.018      0.986      -0.013       0.013
# ph             0.0756      0.024      3.152      0.002       0.028       0.123
# ==============================================================================
# Omnibus:                       16.952   Durbin-Watson:                   1.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.596
# Skew:                          -0.388   Prob(JB):                     3.46e-15
# Kurtosis:                       7.551   Cond. No.                     3.27e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.27e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Small code to automatically write the python directly from the linear regression results

# %%
import string

print("def eOut0(P):")
ret="    return np.exp("
for (x,y) in zip(string.ascii_uppercase[:len(X.columns)],X.columns):
    print("    "+x+"="+str(est.params[y])+"    #"+y)
    if y=='const':
        ret=ret+x+"+"   
    else:   
        ret=ret+x+"*P['"+y+"']+"
print(ret[:-1]+")")
        
print("def eOut(P):")
for (x,y) in zip(string.ascii_uppercase[:len(X.columns)],X.columns):
    print("    "+x+"=np.random.normal("+str(est.params[y])+","+str(est.bse[y])+")    #"+y)

print(ret[:-1]+")")
# Out:
# def eOut0(P):
#     A=1.3529312060941647    #const
#     B=0.0016362141049857705    #mg
#     C=-8.196073337777638e-06    #ca
#     D=-0.0049871888864530655    #s
#     E=1.7076258958316184    #ewe
#     F=-0.00011957753143042316    #t
#     G=0.07557845354792651    #ph
#     return np.exp(A+B*P['mg']+C*P['ca']+D*P['s']+E*P['ewe']+F*P['t']+G*P['ph'])
# def eOut(P):
#     A=np.random.normal(1.3529312060941647,0.35421523420348194)    #const
#     B=np.random.normal(0.0016362141049857705,0.0001816070254566603)    #mg
#     C=np.random.normal(-8.196073337777638e-06,1.5739463852203642e-05)    #ca
#     D=np.random.normal(-0.0049871888864530655,0.0022209604229630527)    #s
#     E=np.random.normal(1.7076258958316184,0.40714694288472036)    #ewe
#     F=np.random.normal(-0.00011957753143042316,0.006561245183509716)    #t
#     G=np.random.normal(0.07557845354792651,0.02397543467409868)    #ph
#     return np.exp(A+B*P['mg']+C*P['ca']+D*P['s']+E*P['ewe']+F*P['t']+G*P['ph'])

# %% [markdown]
# # Code for the linear regression model for the GEDx component
# Just copy pasted from the output of the cell above. The first function calculates energy intput values directly from the mean values of parameters from the regression analysis.
# The second function calculates energy input values from randomly selected parameters. The probability distribution for the parameters are also from the regression analysis above.

# %%
def eOut0(P):
    A=1.3529312060941647    #const
    B=0.0016362141049857705    #mg
    C=-8.196073337777638e-06    #ca
    D=-0.0049871888864530655    #s
    E=1.7076258958316184    #ewe
    F=-0.00011957753143042316    #t
    G=0.07557845354792651    #ph
    return np.exp(A+B*P['mg']+C*P['ca']+D*P['s']+E*P['ewe']+F*P['t']+G*P['ph'])
def eOut(P):
    A=np.random.normal(1.3529312060941647,0.35421523420348194)    #const
    B=np.random.normal(0.0016362141049857705,0.0001816070254566603)    #mg
    C=np.random.normal(-8.196073337777638e-06,1.5739463852203642e-05)    #ca
    D=np.random.normal(-0.0049871888864530655,0.0022209604229630527)    #s
    E=np.random.normal(1.7076258958316184,0.40714694288472036)    #ewe
    F=np.random.normal(-0.00011957753143042316,0.006561245183509716)    #t
    G=np.random.normal(0.07557845354792651,0.02397543467409868)    #ph
    return np.exp(A+B*P['mg']+C*P['ca']+D*P['s']+E*P['ewe']+F*P['t']+G*P['ph'])

# %% [markdown]
# # Prediction of energy input calculated using the model
# Here we load in all the available data, including the brine data from Romania

# %%
dfAll=pd.read_pickle('Data\dfAll.pickle')
dfAll.columns = dfAll.columns.str.strip()\
                     .str.lower()\
                     .str.replace('+','')\
                     .str.replace('^','')\
                     .str.replace(' ', '_')\
                     .str.replace('[', '')\
                     .str.replace(']', '')\
                     .str.replace('/', '')\
                     .str.replace('_mgl','')
dfAll.columns = dfAll.columns.str.replace('salinity_gl','s')\
                             .str.replace('temperature','t')
dfAll['brine_origin']=dfAll['brine_origin'].fillna('LAB')

# %% [markdown]
# The model values, upper and lower standard deviation bounds and model error calculated

# %%
dfAll['energy_input_model']=dfAll.apply(lambda row: eOut0(row), axis=1)

dfAll[['e2p3','e15p9','e84p1','e97p7']]=dfAll.apply(lambda row: pd.Series(np.round(np.percentile([eOut(row) for i in range(1000)],[2.3,15.9,84.1,97.7]),1)),axis=1)

dfAll['model Error']=dfAll['energy_input_kwhkg_metal_rem.']-dfAll['energy_input_model']

# %% [markdown]
# Plotting the comparison of the model to the measurements. Note that the Romanian samples where not included in the fit. Including them increases the errorbars substantially.

# %%
plt.rcParams.update({'font.size': 16})
colors = {'ENGLAND':'C1', 'ICELAND':'C2', 'BELGIUM':'C3', 'ROMANIA':'C4','LAB':'C5'}
fig,ax=plt.subplots(figsize=(24,8))

#-------plotting the 68 % error bars------------------------------------------------
ax.errorbar(dfAll['energy_input_model'].index+1,
            dfAll['energy_input_model'].values,
            yerr=np.vstack([dfAll['energy_input_model'].values-dfAll['e15p9'].values,
                            dfAll['e84p1'].values-dfAll['energy_input_model'].values]),
            capsize=4,
            capthick=4,
            linewidth=4,
            fmt ='none',
            zorder=20,
            label='Model results within 68%')

#-------plotting the 95 % error bars------------------------------------------------
ax.errorbar(dfAll['energy_input_model'].index+1,
            dfAll['energy_input_model'].values,
            yerr=np.vstack([dfAll['energy_input_model'].values-dfAll['e2p3'].values,
                            dfAll['e97p7'].values-dfAll['energy_input_model'].values]),
            capsize=0,
            capthick=1,
            linewidth=2,
            color='grey',
            fmt ='none',
            zorder=10,
            label='Model results within 95%')

#-------plotting the measured samples and coloring the background to indicate sample origin----------------------
for origin in ['ENGLAND','ICELAND','BELGIUM','ROMANIA','LAB']:
    subdf=dfAll[dfAll['brine_origin']==origin]
    ax.scatter(subdf.index+1, subdf['energy_input_kwhkg_metal_rem.'], color=subdf['brine_origin'].apply(lambda x: colors[x]),s=60,edgecolor='k',lw=2,zorder=30,label=origin.title()+" samples")
    plt.axvspan(subdf.index[0]+1-0.5,subdf.index[-1]+1+0.5, color=colors[origin],alpha=0.15)
    
#-------plotting the model result----------------------------------------------------
ax.scatter(dfAll.index+1,dfAll['energy_input_model'],color='C0',s=60,edgecolor='k',zorder=20,label='Model result')

#-------plotting the model error----------------------------------------------------
ax.bar(dfAll.index+1,dfAll['model Error'],color='red',alpha=0.4,zorder=0,label='Model Error')


#------tweaking the look of the plot------------------------------------------------
ax.set_xticks(range(len(dfAll)+1))
ax.set_ylim(-20,210)
ax.set_xlim(0.4,79.5)
ax.set_yticks(range(-20,210,20))
ax.set_ylabel("Energy input [kWh/(m$^3$kg)]")
ax.set_xlabel("Sample No. ")
plt.xticks(rotation=-90)
ax.grid(linestyle='dotted')
ax.legend(ncol=2,loc=2)
plt.savefig("GEDx_Energy_Model.png", bbox_inches='tight')

# %% [markdown]
# Histograms of the energy distrubtions created by the model compared for each sample

# %%
fig,ax=plt.subplots(14,6,figsize=(15,10),sharex=True)
for n in range(79):
    ax[n//6][n%6].hist([eOut(dfAll.iloc[n]) for i in range(1000)],20,label=None,alpha=0.5);
    ax[n//6][n%6].axvline(dfAll['energy_input_kwhkg_metal_rem.'].iloc[n],color='C1',label='Sample No.'+str(n+1),alpha=0.8);
    ax[n//6][n%6].axvline(dfAll['energy_input_model'].iloc[n],color='C0',label=None,alpha=0.8);
    ax[n//6][n%6].legend(fontsize=10,frameon=False)
    
for n in range(14*6):
    ax[n//6][n%6].set_yticks([])
    ax[n//6][n%6].set_xlim(0,200)
    ax[n//6][n%6].set_xticks([0,100])

plt.tight_layout(pad=-0.5)
plt.savefig("GEDx_Energy_Model_histograms.png", bbox_inches='tight')
