# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as ss

# %% [markdown]
# # Linear regression model for predicting output ratio of metals
# We start by looking at the correlation between selected parameters

# %%
df7=pd.read_pickle("Data\df7.pickle")
df7.columns = df7.columns.str.strip()\
                         .str.lower()\
                         .str.replace('+','')\
                         .str.replace('^','')\
                         .str.replace(' ', '_')\
                         .str.replace('[', '')\
                         .str.replace(']', '')\
                         .str.replace('/', '')\
                         .str.replace('_mgl','')

df7.columns = df7.columns.str.replace('salinity_gl','s')\
                         .str.replace('temperature','t')
df7[['mg','ca','li_outin_ratio','al_outin_ratio','ph','s','ewe','t']].corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col0 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col1 {
#             background-color:  #f1ebf5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col3 {
#             background-color:  #8cb3d5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col4 {
#             background-color:  #b0c2de;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col5 {
#             background-color:  #f5eef6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col7 {
#             background-color:  #fbf3f9;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col0 {
#             background-color:  #ece7f2;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col1 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col2 {
#             background-color:  #a5bddb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col3 {
#             background-color:  #9ab8d8;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col4 {
#             background-color:  #b0c2de;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col5 {
#             background-color:  #f4edf6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col6 {
#             background-color:  #fdf5fa;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row1_col7 {
#             background-color:  #f9f2f8;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col1 {
#             background-color:  #afc1dd;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col2 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col3 {
#             background-color:  #b9c6e0;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col4 {
#             background-color:  #8fb4d6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col5 {
#             background-color:  #a2bcda;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col6 {
#             background-color:  #f5eff6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row2_col7 {
#             background-color:  #f8f1f8;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col0 {
#             background-color:  #d1d2e6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col1 {
#             background-color:  #e4e1ef;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col2 {
#             background-color:  #f3edf5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col3 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col4 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col5 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col6 {
#             background-color:  #f9f2f8;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row3_col7 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col0 {
#             background-color:  #ede8f3;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col1 {
#             background-color:  #f3edf5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col2 {
#             background-color:  #d3d4e7;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col3 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col4 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col5 {
#             background-color:  #eae6f1;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col6 {
#             background-color:  #f1ebf5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row4_col7 {
#             background-color:  #f1ebf4;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col0 {
#             background-color:  #f8f1f8;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col1 {
#             background-color:  #fcf4fa;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col2 {
#             background-color:  #a7bddb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col3 {
#             background-color:  #d2d2e7;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col4 {
#             background-color:  #b0c2de;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col5 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col6 {
#             background-color:  #fbf3f9;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row5_col7 {
#             background-color:  #f7f0f7;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col0 {
#             background-color:  #fbf4f9;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col1 {
#             background-color:  #fff7fb;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col2 {
#             background-color:  #f1ebf5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col3 {
#             background-color:  #bdc8e1;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col4 {
#             background-color:  #b0c2de;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col5 {
#             background-color:  #f4edf6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col6 {
#             background-color:  #023858;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row6_col7 {
#             background-color:  #faf2f8;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col0 {
#             background-color:  #f7f0f7;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col1 {
#             background-color:  #fbf4f9;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col2 {
#             background-color:  #f4eef6;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col3 {
#             background-color:  #c8cde4;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col4 {
#             background-color:  #b0c2de;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col5 {
#             background-color:  #f1ebf5;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col6 {
#             background-color:  #faf3f9;
#         }    #T_081bc134_38fc_11e9_8493_d4258bcadf72row7_col7 {
#             background-color:  #023858;
#         }</style>
# <table id="T_081bc134_38fc_11e9_8493_d4258bcadf72" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >mg</th>
#         <th class="col_heading level0 col1" >ca</th>
#         <th class="col_heading level0 col2" >li_outin_ratio</th>
#         <th class="col_heading level0 col3" >al_outin_ratio</th>
#         <th class="col_heading level0 col4" >ph</th>
#         <th class="col_heading level0 col5" >s</th>
#         <th class="col_heading level0 col6" >ewe</th>
#         <th class="col_heading level0 col7" >t</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_081bc134_38fc_11e9_8493_d4258bcadf72level0_row0" class="row_heading level0 row0" >mg</th>
#         <td id="T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col0" class="data row0 col0" >1</td>
#         <td id="T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col1" class="data row0 col1" >0.0096</td>
#         <td id="T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col2" class="data row0 col2" >-0.13</td>
#         <td id="T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col3" class="data row0 col3" >0.15</td>
#         <td id="T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col4" class="data row0 col4" >0</td>
#         <td id="T_081bc134_38fc_11e9_8493_d4258bcadf72row0_col5" class="data row0 col5" >-0.078</t

# %%
epsLi=5e-3
LiMax=0.4
df7['li_outin_ratio_logit']=np.where(df7['li_outin_ratio']<epsLi,
                                     np.log((df7['li_outin_ratio']+epsLi)/(LiMax-df7['li_outin_ratio']-epsLi)),
                                     np.log(df7['li_outin_ratio']/(LiMax-df7['li_outin_ratio']))
                                     )
epsAl=2e-2
df7['al_outin_ratio_logit']=np.where(df7['al_outin_ratio']==1.0,
                                     np.log((df7['al_outin_ratio']-epsAl)/(1.0-df7['al_outin_ratio']+epsAl)),
                                     np.log(df7['al_outin_ratio']/(1.0-df7['al_outin_ratio']))
                                     )
# Out:
# C:\Users\gth\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
#Features selected for the regression model
X=df7[['mg','ca','ph','s','ewe','t']]
X=X.fillna(0)
X=sm.add_constant(X)

#Labels selected for the regression model
YAl=df7['al_outin_ratio_logit']
YLi=df7['li_outin_ratio_logit']

#The aluminum extraction model fitted
estAl=sm.OLS(YAl,X)
estAl=estAl.fit()
#print(estAl.summary())

#The lithium extraction model fitted
estLi=sm.OLS(YLi,X)
estLi=estLi.fit()
#print(estLi.summary())

# %% [markdown]
# # Small code to automatically write the python directly from the linear regression results

# %%
import string
############################################################################################
print("def alOut0(P):")
out="    out="
for (x,y) in zip(string.ascii_uppercase[:len(X.columns)],X.columns):
    print("    "+x+"="+str(estAl.params[y])+"    #"+y)
    if y=='const':
        out=out+x+"+"   
    else:   
        out=out+x+"*P['"+y+"']+"
print(out[:-1])
print("    return 1.0/(1.0+np.exp(-out))")
        
print("def alOut(P):")
for (x,y) in zip(string.ascii_uppercase[:len(X.columns)],X.columns):
    print("    "+x+"=np.random.normal("+str(estAl.params[y])+","+str(estAl.bse[y])+")    #"+y)

print(out[:-1])
print("    return 1.0/(1.0+np.exp(-out))")
############################################################################################
print("def liOut0(P):")
out="    out="
for (x,y) in zip(string.ascii_uppercase[:len(X.columns)],X.columns):
    print("    "+x+"="+str(estLi.params[y])+"    #"+y)
    if y=='const':
        out=out+x+"+"   
    else:   
        out=out+x+"*P['"+y+"']+"
print(out[:-1])
print("    return "+str(LiMax)+"/(1.0+np.exp(-out))")
        
print("def liOut(P):")
for (x,y) in zip(string.ascii_uppercase[:len(X.columns)],X.columns):
    print("    "+x+"=np.random.normal("+str(estLi.params[y])+","+str(estLi.bse[y])+"*"+str(0.4)+")    #"+y)

print(out[:-1])
print("    return "+str(LiMax)+"/(1.0+np.exp(-out))")
# Out:
# def alOut0(P):
#     A=9.243112683565625    #const
#     B=0.0007290528430428293    #mg
#     C=2.3766108826381692e-05    #ca
#     D=-0.6104172351984469    #ph
#     E=-0.01023763417929939    #s
#     F=-0.8547529374417671    #ewe
#     G=0.0077546360321853955    #t
#     out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
#     return 1.0/(1.0+np.exp(-out))
# def alOut(P):
#     A=np.random.normal(9.243112683565625,1.173464899400799)    #const
#     B=np.random.normal(0.0007290528430428293,0.0005482925615291159)    #mg
#     C=np.random.normal(2.3766108826381692e-05,4.982003931049452e-05)    #ca
#     D=np.random.normal(-0.6104172351984469,0.09299424362214656)    #ph
#     E=np.random.normal(-0.01023763417929939,0.006459516129063303)    #s
#     F=np.random.normal(-0.8547529374417671,1.1856402922543547)    #ewe
#     G=np.random.normal(0.0077546360321853955,0.025068322281798946)    #t
#     out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
#     return 1.0/(1.0+np.exp(-out))
# def liOut0(P):
#     A=-2.166550880352732    #const
#     B=-0.00038544070761357166    #mg
#     C=0.0001293845078422753    #ca
#     D=0.1054253807914887    #ph
#     E=0.01679336165131661    #s
#     F=0.21394153681811745    #ewe
#     G=0.0005523783360058092    #t
#     out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
#     return 0.4/(1.0+np.exp(-out))
# def liOut(P):
#     A=np.random.normal(-2.166550880352732,1.3101146056856243*0.4)    #const
#     B=np.random.normal(-0.00038544070761357166,0.0006121410989070693*0.4)    #mg
#     C=np.random.normal(0.0001293845078422753,5.562157094757528e-05*0.4)    #ca
#     D=np.random.normal(0.1054253807914887,0.10382340100353452*0.4)    #ph
#     E=np.random.normal(0.01679336165131661,0.0072117252341071065*0.4)    #s
#     F=np.random.normal(0.21394153681811745,1.3237078201188375*0.4)    #ewe
#     G=np.random.normal(0.0005523783360058092,0.02798752240326006*0.4)    #t
#     out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
#     return 0.4/(1.0+np.exp(-out))

# %%
def alOut0(P):
    A=9.243112683565625    #const
    B=0.0007290528430428293    #mg
    C=2.3766108826381692e-05    #ca
    D=-0.6104172351984469    #ph
    E=-0.01023763417929939    #s
    F=-0.8547529374417671    #ewe
    G=0.0077546360321853955    #t
    out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
    return 1.0/(1.0+np.exp(-out))
def alOut(P):
    A=np.random.normal(9.243112683565625,1.173464899400799)    #const
    B=np.random.normal(0.0007290528430428293,0.0005482925615291159)    #mg
    C=np.random.normal(2.3766108826381692e-05,4.982003931049452e-05)    #ca
    D=np.random.normal(-0.6104172351984469,0.09299424362214656)    #ph
    E=np.random.normal(-0.01023763417929939,0.006459516129063303)    #s
    F=np.random.normal(-0.8547529374417671,1.1856402922543547)    #ewe
    G=np.random.normal(0.0077546360321853955,0.025068322281798946)    #t
    out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
    return 1.0/(1.0+np.exp(-out))
def liOut0(P):
    A=-2.166550880352732    #const
    B=-0.00038544070761357166    #mg
    C=0.0001293845078422753    #ca
    D=0.1054253807914887    #ph
    E=0.01679336165131661    #s
    F=0.21394153681811745    #ewe
    G=0.0005523783360058092    #t
    out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
    return 0.4/(1.0+np.exp(-out))
def liOut(P):
    A=np.random.normal(-2.166550880352732,1.3101146056856243*0.4)    #const
    B=np.random.normal(-0.00038544070761357166,0.0006121410989070693*0.4)    #mg
    C=np.random.normal(0.0001293845078422753,5.562157094757528e-05*0.4)    #ca
    D=np.random.normal(0.1054253807914887,0.10382340100353452*0.4)    #ph
    E=np.random.normal(0.01679336165131661,0.0072117252341071065*0.4)    #s
    F=np.random.normal(0.21394153681811745,1.3237078201188375*0.4)    #ewe
    G=np.random.normal(0.0005523783360058092,0.02798752240326006*0.4)    #t
    out=A+B*P['mg']+C*P['ca']+D*P['ph']+E*P['s']+F*P['ewe']+G*P['t']
    return 0.4/(1.0+np.exp(-out))

# %%
df7['al_outin_ratio_model']=df7.apply(lambda row: alOut0(row), axis=1)
df7[['al2p3','al15p9','al84p1','al97p7']]=df7.apply(lambda row: pd.Series(np.round(np.percentile([alOut(row) for i in range(1000)],[2.3,15.9,84.1,97.7]),1)),axis=1)
df7['al_model_error']=df7['al_outin_ratio_model']-df7['al_outin_ratio']

df7['li_outin_ratio_model']=df7.apply(lambda row: liOut0(row), axis=1)
df7[['li2p3','li15p9','li84p1','li97p7']]=df7.apply(lambda row: pd.Series(np.round(np.percentile([liOut(row) for i in range(1000)],[2.3,15.9,84.1,97.7]),1)),axis=1)
df7['li_model_error']=df7['li_outin_ratio_model']-df7['li_outin_ratio']

# %%
plt.rcParams.update({'font.size': 16})
fig,ax=plt.subplots(figsize=(22,8))


ax.errorbar(df7['al_outin_ratio_model'].index+7,
            df7['al_outin_ratio_model'].values,
            yerr=np.vstack([df7['al_outin_ratio_model'].values-df7['al15p9'].values,
                            df7['al84p1'].values-df7['al_outin_ratio_model'].values]),
            capsize=4,
            capthick=4,
            linewidth=4,
            fmt ='none',
            zorder=10,
            label='Model results within 68%')

ax.errorbar(df7['al_outin_ratio_model'].index+7,
            df7['al_outin_ratio_model'].values,
            yerr=np.vstack([df7['al_outin_ratio_model'].values-df7['al2p3'].values,
                            df7['al97p7'].values-df7['al_outin_ratio_model'].values]),
            capsize=0,
            capthick=1,
            color='gray',
            fmt ='none',
            zorder=5,
            label='Model results within 95%$')

#for origin in ['ENGLAND','ICELAND','BELGIUM','ROMANIA','LAB']:
#    subdf=dfAll[dfAll['brine_origin']==origin]
ax.scatter(df7.index+7, df7['al_outin_ratio'],color='C1',s=60,edgecolor='k',lw=2,zorder=20,label='Measured values')
ax.scatter(df7.index+7, df7['al_outin_ratio_model'],color='C0',s=60,edgecolor='k',lw=2,zorder=20,label='Model values')
ax.set_xticks([i+7 for i in range(len(df7))])
ax.set_xlim(6,len(df7)+7)
ax.set_yticks([i/10 for i in range(-1,11,1)])
ax.set_ylabel("Al recovery ratio")
ax.set_xlabel("Sample No. ")
plt.xticks(rotation=-90)
ax.grid(linestyle='dotted')
ax.bar(df7.index+7,df7['al_model_error'],color='red',alpha=0.3,zorder=0,label='Model Error')
ax.legend(ncol=2,bbox_to_anchor=(1, -0.1))
plt.savefig("GDEx_Al_Model.png", bbox_inches='tight')

# %%
fig,ax=plt.subplots(12,6,figsize=(15,10),sharex=True)
for n in range(68):
    ax[n//6][n%6].hist([alOut(df7.iloc[n]) for i in range(1000)],40,label=None,alpha=0.6);
    ax[n//6][n%6].axvline(df7['al_outin_ratio'].iloc[n],color='C1',label='Sample No.'+str(n+7));
    ax[n//6][n%6].axvline(df7['al_outin_ratio_model'].iloc[n],color='C0',label=None);
    ax[n//6][n%6].legend(fontsize=10,frameon=False)
    
for n in range(12*6):
    ax[n//6][n%6].set_yticks([])
    ax[n//6][n%6].set_xlim(0,1)
    ax[n//6][n%6].set_xticks([0,0.5])

plt.tight_layout(pad=-1)
plt.savefig("GEDx_Al_Model_histograms.png", bbox_inches='tight')

# %%
plt.rcParams.update({'font.size': 16})
fig,ax=plt.subplots(figsize=(22,8))

ax.errorbar(df7['li_outin_ratio_model'].index+7,
            df7['li_outin_ratio_model'].values,
            yerr=np.vstack([df7['li_outin_ratio_model'].values-df7['li15p9'].values,
                            df7['li84p1'].values-df7['li_outin_ratio_model'].values]),
            capsize=4,
            capthick=4,
            linewidth=4,
            fmt ='none',
            zorder=10,
            label='Model results within 68%')

ax.errorbar(df7['li_outin_ratio_model'].index+7,
            df7['li_outin_ratio_model'].values,
            yerr=np.vstack([df7['li_outin_ratio_model'].values-df7['li2p3'].values,
                            df7['li97p7'].values-df7['li_outin_ratio_model'].values]),
            capsize=0,
            capthick=1,
            color='gray',
            fmt ='none',
            zorder=5,
            label='Model results within 95%')

ax.scatter(df7.index+7, df7['li_outin_ratio'],color='C1',s=60,edgecolor='k',lw=2,zorder=20,label='Measured values')
ax.scatter(df7.index+7, df7['li_outin_ratio_model'],color='C0',s=60,edgecolor='k',lw=2,zorder=20,label='Model values')
ax.set_xticks(range(7,len(df7)+7))
ax.set_xlim(6,len(df7)+7)
ax.set_ylabel("Li recovery ratio")
ax.set_ylim([-0.4,1.0])
ax.set_xlabel("Sample No. ")
plt.xticks(rotation=-90)
ax.grid(linestyle='dotted')
ax.bar(df7.index+7,df7['li_model_error'],color='red',alpha=0.3,zorder=0,label='Model Error')
ax.legend(ncol=2)
plt.savefig("GDEx_Li_Model.png", bbox_inches='tight')

# %%
fig,ax=plt.subplots(12,6,figsize=(15,10),sharex=True)
for n in range(68):
    ax[n//6][n%6].hist([liOut(df7.iloc[n]) for i in range(1000)],40,label=None,alpha=0.6);
    ax[n//6][n%6].axvline(df7['li_outin_ratio'].iloc[n],color='C1',label='Sample No.'+str(n+7));
    ax[n//6][n%6].axvline(df7['li_outin_ratio_model'].iloc[n],color='C0',label=None);
    ax[n//6][n%6].legend(fontsize=10,frameon=False)
    
for n in range(12*6):
    ax[n//6][n%6].set_yticks([])
    ax[n//6][n%6].set_xlim(0,1)
    ax[n//6][n%6].set_xticks([0,0.5])

plt.tight_layout(pad=-1)
plt.savefig("GEDx_Li_Model_histograms.png", bbox_inches='tight')
