# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
import re
import ResultToolbox as rt

# %% [markdown]
# # Read in histogram data

# %%
df=pd.read_csv("Full_System/Landau/Results_Landau10000.0.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# &lt;ipython-input-2-ffaa2170e684&gt; in &lt;module&gt;
# ----&gt; 1 df=pd.read_csv(&quot;Full_System/Landau/Results_Landau10000.0.csv&quot;)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %% [markdown]
# # Input parameters

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['s'],ax,"Salinity [g/L]",ymax=400)
ax.text(0.1,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Salinity_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['t'],ax,"Temperature [°C]",ymax=500)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Temperature_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['q'],ax,"Flow rate [L/s]",ymax=500)
ax.text(0.1,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Flowrate_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ph'],ax,"pH [-]",ymax=400)
ax.text(0.1,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_ph_input.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# # Net Energy production

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E'],ax,"Electricity [MW]",ymax=2000,xrange=[-1,1.7])
ax.text(0.1,0.9,"(e)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Netto_Energy.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# # Energy Production per component

# %%
fig, ax=plt.subplots(figsize=(8,4))
rt.plot_histogram(df['E3'],
                  ax,
                  "Energy consumed by Electrolysis component [MW]",
                  xrange=[-0.3,0],
                  ymax=1500)
ax.text(0.1,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Elecrolysis_Energy.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E4'],ax,"Energy from Geothermal Plant [MW]",ymax=500)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Gethermal_Electric_Energy.png",dpi=300,bbox_inches='tight')

#------------------Does not vary---------------------------------------
#fig, ax=plt.subplots(figsize=(6,4))
#rt.plot_histogram(df['H4'],ax[1],"Heat from Geothermal Plant [MW]",ymax=500, ylabel=False)
#plt.savefig("Full_System/Balmatt/Balmat_Gethermal_Electric_Energy.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(8,4))
rt.plot_histogram(df['E5'],
                  ax,
                  "Energy consumed by Gas Diffusion component [MW]",
                  ymax=1000,
                  xrange=[-2,0],
                  nbins=150
                  )
ax.text(0.05,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_energy.png",dpi=300,bbox_inches='tight')



fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E6'],ax,"Energy from Salt Gradient Component [MW]",ymax=500, ylabel=False)
ax.text(0.1,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Saltgradient_Energy.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# # Metal Extracted

# %%
df.columns[df.columns.str.contains('_3')]
# Out:
# Index(['cu_3', 'as_3', 'sr_3', 'pb_3', 'al_3', 'zn_3', 'li_3', 'ni_3', 'cd_3'], dtype='object')

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['as_3'],ax,"As [mg/L]",ymax=300)#,xrange=[1,2.2])
ax.text(0.05,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Electrolysis_as.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cu_3'],ax,"Cu [mg/L]",ymax=700)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Electrolysis_cu.png",dpi=300,bbox_inches='tight')

# %%
df.columns[df.columns.str.contains('_5')]
# Out:
# Index(['sr_5', 'ni_5', 'mn_5', 'li_5', 'rb_5', 'as_5', 'zn_5', 'al_5', 'f__5',
#        'br_5', 'b__5', 'hg_5', 'fe_5', 'cd_5', 'cu_5', 'pb_5'],
#       dtype='object')

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['li_5'],ax,"Li [mg/L]",ymax=1500,xrange=[0,70])
ax.text(0.05,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_li.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['al_5'],ax,"Al [mg/L]",ymax=300)#,xrange=[1,2.2])
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_al.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ni_5'],ax,"Ni [mg/L]",ymax=300)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_ni.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['sr_5'],ax,"Sr [mg/L]",ymax=300)
ax.text(0.1,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_sr.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['zn_5'],ax,"Zn [mg/L]",ymax=300)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_zn.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['mn_5'],ax,"Mn [mg/L]",ymax=300)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_mn.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cu_5'],ax,"Cu [mg/L]",ymax=300)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_cu.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['pb_5'],ax,"Pb [mg/L]",ymax=300)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_pb.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cd_5'],ax,"Cd [mg/L]",ymax=300)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_cd.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['rb_5'],ax,"Rb [mg/L]",ymax=400)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_rb.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['as_5'],ax,"As [mg/L]",ymax=400)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_as.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['fe_5'],ax,"Fe [mg/L]",ymax=600)
ax.text(0.11,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_fe.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['br_5'],ax,"Br [mg/L]",ymax=300)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_br.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['f__5'],ax,"F [mg/L]",ymax=900)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_f.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['b__5'],ax,"B [mg/L]",ymax=900)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_b.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['hg_5'],ax,"Hg [mg/L]",ymax=900)
plt.savefig("Full_System/Landau/Landau_Gasdiffusion_hg.png",dpi=300,bbox_inches='tight')
