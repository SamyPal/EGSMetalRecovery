# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
import re
import ResultToolbox as rt

# %% [markdown]
# # Read in histogram data

# %%
df=pd.read_csv("Full_System/Reykjanes/Results_ReykjanesDeep5000.0.csv")

# %% [markdown]
# # Input parameters

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['s'],ax,"Salinity [g/L]",ymax=300)
ax.text(0.1,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Salinity_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['t'],ax,"Temperature [°C]",ymax=300)
plt.savefig("Full_System/Reykjanes/Reykjanes_Temperature_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['q'],ax,"Flow rate [L/s]",ymax=300)
plt.savefig("Full_System/Reykjanes/Reykjanes_Flowrate_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ph'],ax,"pH [-]",ymax=300)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_ph_input.png",dpi=300,bbox_inches='tight')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# # Net Power production

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E'],ax,"Net electric power [MW]",ymax=2000,xrange=[2,3.5])
ax.text(0.05,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Netto_Energy.png",dpi=300,bbox_inches='tight')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# # Energy Production per component

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E3'],
                  ax,
                  "Power consumed by electrolytic component [MW]",
                  xrange=[-0.7,-0.1],
                  ymax=2500)
ax.text(0.1,0.9,"(a)",transform=ax.transAxes)
#ax.set_xticks([-0.02,-0.015,-0.01,-0.005,0])
plt.savefig("Full_System/Reykjanes/Reykjanes_Elecrolysis_Energy.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E4'],ax,"Power from geothermal plant [MW]",ymax=500)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Gethermal_Electric_Energy.png",dpi=300,bbox_inches='tight')

#------------------Does not vary---------------------------------------
#fig, ax=plt.subplots(figsize=(6,4))
#rt.plot_histogram(df['H4'],ax[1],"Heat from Geothermal Plant [MW]",ymax=500, ylabel=False)
#plt.savefig("Full_System/Balmatt/Balmat_Gethermal_Electric_Energy.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E5'],
                  ax,
                  "Power consumed by gas diffusion component [MW]",
                  ymax=1800,
                  xrange=[-1.25,0],

                  )
ax.text(0.05,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Gasdiffusion_energy.png",dpi=300,bbox_inches='tight')



fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E6'],ax,"Power from salt gradient component [MW]",ymax=300, ylabel=False)
ax.text(0.1,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Saltgradient_Energy.png",dpi=300,bbox_inches='tight')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# # Metal Extracted

# %%
df.columns[df.columns.str.contains('_3')]
# Out:
# Index([&#39;cu_3&#39;, &#39;au_3&#39;, &#39;as_3&#39;, &#39;sb_3&#39;, &#39;sr_3&#39;, &#39;ba_3&#39;, &#39;pb_3&#39;, &#39;ag_3&#39;, &#39;co_3&#39;,
#        &#39;zn_3&#39;, &#39;li_3&#39;, &#39;ni_3&#39;, &#39;cd_3&#39;, &#39;mo_3&#39;],
#       dtype=&#39;object&#39;)

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cu_3'],ax,"Cu [mg/L]",ymax=500)#,xrange=[1,2.2])
ax.text(0.1,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Electrolysis_cu.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['as_3'],ax,"As [mg/L]",ymax=500)#,xrange=[1,2.2])
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Electrolysis_as.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ag_3'],ax,"Ag [mg/L]",ymax=300)#,xrange=[1,2.2])
ax.text(0.1,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Electrolysis_ag.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['sb_3'],ax,"Sb [mg/L]",ymax=300)#,xrange=[1,2.2])
ax.text(0.1,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Electrolysis_sb.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['au_3'],ax,"Au [mg/L]",ymax=300)#,xrange=[1,2.2])
ax.text(0.1,0.9,"(e)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Electrolysis_au.png",dpi=300,bbox_inches='tight')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
df.columns[df.columns.str.contains('_5')]
# Out:
# Index([&#39;ba_5&#39;, &#39;li_5&#39;, &#39;zn_5&#39;, &#39;ni_5&#39;, &#39;as_5&#39;, &#39;mn_5&#39;, &#39;sr_5&#39;, &#39;b__5&#39;, &#39;cu_5&#39;,
#        &#39;pb_5&#39;, &#39;se_5&#39;, &#39;br_5&#39;, &#39;cr_5&#39;, &#39;au_5&#39;, &#39;sb_5&#39;, &#39;cd_5&#39;, &#39;mo_5&#39;, &#39;ag_5&#39;,
#        &#39;hg_5&#39;, &#39;fe_5&#39;, &#39;co_5&#39;],
#       dtype=&#39;object&#39;)

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['fe_5'],ax,"Fe [mg/L]",ymax=800)
ax.text(0.15,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Gasdiffusion_fe.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['br_5'],ax,"Br [mg/L]",ymax=300)#,xrange=[1,2.2])
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Gasdiffusion_br.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['zn_5'],ax,"Zn [mg/L]",ymax=500)
ax.text(0.1,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Gasdiffusion_zn.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cu_5'],ax,"Cu [mg/L]",ymax=500)
ax.text(0.15,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Reykjanes/Reykjanes_Gasdiffusion_cu.png",dpi=300,bbox_inches='tight')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
