# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
import re
import ResultToolbox as rt

# %% [markdown]
# # Read in histogram data

# %%
df=pd.read_csv("Full_System\Balmatt\Results_Balmatt10000.0.csv")

# %% [markdown]
# # Input parameters

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['s'],ax,"Salinity [g/L]",ymax=500)
ax.text(0.05,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Salinity_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['t'],ax,"Temperature [°C]",ymax=500)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Temperature_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['q'],ax,"Flow rate [L/s]",ymax=500)
ax.text(0.1,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Flowrate_input.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ph'],ax,"pH [-]",ymax=400)
ax.text(0.1,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_ph_input.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# # Net Energy production

# %%
fig, ax=plt.subplots(figsize=(8,4))
rt.plot_histogram(df['E'],ax,"Electricity [MW]",ymax=2500,xrange=[-4,1])
ax.text(0.05,0.9,"(e)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Netto_Energy.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# # Energy Production per component

# %%
fig, ax=plt.subplots(figsize=(8,4))
rt.plot_histogram(df['E3'],
                  ax,
                  "Energy consumed by Electrolysis component [MW]",
                  ymax=1500,
                  xrange=[-0.0004,0])
ax.text(0.05,0.9,"(a)",transform=ax.transAxes)
ax.set_xticks([-0.0004,-0.0003,-0.0002,-0.0001,0,])
plt.savefig("Full_System/Balmatt/Balmat_Elecrolysis_Energy.png",dpi=300,bbox_inches='tight')


fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E4'],ax,"Energy from Geothermal Plant [MW]",ymax=500)
ax.text(0.05,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Gethermal_Electric_Energy.png",dpi=300,bbox_inches='tight')

#------------------Does not vary---------------------------------------
#fig, ax=plt.subplots(figsize=(6,4))
#rt.plot_histogram(df['H4'],ax[1],"Heat from Geothermal Plant [MW]",ymax=500, ylabel=False)
#plt.savefig("Full_System/Balmatt/Balmat_Gethermal_Electric_Energy.png",dpi=300,bbox_inches='tight')


fig, ax=plt.subplots(figsize=(8,4))
rt.plot_histogram(df['E5'],
                  ax,
                  "Energy consumed by Gas Diffusion component [MW]",
                  ymax=1200,
                  ylabel=False,
                  xrange=[-4,0],
                  nbins=150
                  )
ax.text(0.1,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_energy.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['E6'],ax,"Energy from Salt Gradient Component [MW]",ymax=500, ylabel=False)
ax.text(0.05,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Saltgradient_Energy.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# # Energy Consumption per component

# %% [markdown]
# # Metal Extracted

# %%
df.columns[df.columns.str.contains('_5')]
# Out:
# Index(['al_5', 'ni_5', 'sr_5', 'mn_5', 'zn_5', 'ba_5', 'cr_5', 'pb_5', 'br_5',
#        'mg_5', 'cu_5', 'cd_5', 'f__5', 'fe_5'],
#       dtype='object')

# %%
fig, ax=plt.subplots(figsize=(8,4))
rt.plot_histogram(df['cu_3'],ax,"Cu [mg/L]",ymax=500)
plt.savefig("Full_System/Balmatt/Balmat_Electrolysis_cu.png",dpi=300,bbox_inches='tight')

# %%
fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ba_5'],ax,"Ba [mg/L]",ymax=300)
ax.text(0.05,0.9,"(d)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_ba.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['al_5'],ax,"Al [mg/L]",ymax=2000,xrange=[1,2.2])
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_al.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['ni_5'],ax,"Ni [mg/L]",ymax=300)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_ni.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['sr_5'],ax,"Sr [mg/L]",ymax=300)
ax.text(0.1,0.9,"(b)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_sr.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['zn_5'],ax,"Zn [mg/L]",ymax=400)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_zn.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['mn_5'],ax,"Mn [mg/L]",ymax=500)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_mn.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cu_5'],ax,"Cu [mg/L]",ymax=400)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_cu.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['pb_5'],ax,"Pb [mg/L]",ymax=400)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_pb.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cd_5'],ax,"Cd [mg/L]",ymax=400)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_cd.png",dpi=300,bbox_inches='tight')

#fig, ax=plt.subplots(figsize=(6,4))
#rt.plot_histogram(df['mg_5'],ax,"Mg [mg/L]",ymax=400)
#plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_mg.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['cr_5'],ax,"Cr [mg/L]",ymax=400)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_cr.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['fe_5'],ax,"Fe [mg/L]",ymax=300)
ax.text(0.09,0.9,"(a)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_fe.png",dpi=300,bbox_inches='tight')

fig, ax=plt.subplots(figsize=(6,4))
rt.plot_histogram(df['br_5'],ax,"Br [mg/L]",ymax=300)
ax.text(0.1,0.9,"(c)",transform=ax.transAxes)
plt.savefig("Full_System/Balmatt/Balmat_Gasdiffusion_br.png",dpi=300,bbox_inches='tight')
